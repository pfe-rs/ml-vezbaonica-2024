# %% [markdown]
# ## Uvod u pandas

# %% [markdown]
# ##### Učitavanje potrebnih biblioteka

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ##### Učitavanje CarPrice_Assignment.csv u dataframe
# Baza koja će se analizirati je - Analiza promene cene automobila (https://www.kaggle.com/datasets/hellbuoy/car-price-prediction)

# %%
car_price_df = pd.read_csv('dataset/CarPrice_Assignment.csv')

car_price_df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %% [markdown]
# ##### Izlistavanje svih kolona

# %%
list(car_price_df.keys())
# Out:
# ['car_ID',
#  'symboling',
#  'CarName',
#  'fueltype',
#  'aspiration',
#  'doornumber',
#  'carbody',
#  'drivewheel',
#  'enginelocation',
#  'wheelbase',
#  'carlength',
#  'carwidth',
#  'carheight',
#  'curbweight',
#  'enginetype',
#  'cylindernumber',
#  'enginesize',
#  'fuelsystem',
#  'boreratio',
#  'stroke',
#  'compressionratio',
#  'horsepower',
#  'peakrpm',
#  'citympg',
#  'highwaympg',
#  'price']

# %%
car_price_df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %% [markdown]
# ##### Izlistavanje svih vrednosti u koloni - carbody

# %%
car_price_df["carbody"]
# Out:
# 0      convertible
# 1      convertible
# 2        hatchback
# 3            sedan
# 4            sedan
#           ...
# 200          sedan
# 201          sedan
# 202          sedan
# 203          sedan
# 204          sedan
# Name: carbody, Length: 205, dtype: object

# %%
set(car_price_df["carbody"])
# Out:
# {'convertible', 'hardtop', 'hatchback', 'sedan', 'wagon'}

# %% [markdown]
# ##### Izdvajanje više karakterističnih kolona

# %%
car_price_df[['car_ID', 'CarName', 'carbody', 'wheelbase', 'stroke', 'price']]
# Out:
#      car_ID                   CarName      carbody  wheelbase  stroke    price
# 0         1        alfa-romero giulia  convertible       88.6    2.68  13495.0
# 1         2       alfa-romero stelvio  convertible       88.6    2.68  16500.0
# 2         3  alfa-romero Quadrifoglio    hatchback       94.5    3.47  16500.0
# 3         4               audi 100 ls        sedan       99.8    3.40  13950.0
# 4         5                audi 100ls        sedan       99.4    3.40  17450.0
# ..      ...                       ...          ...        ...     ...      ...
# 200     201           volvo 145e (sw)        sedan      109.1    3.15  16845.0
# 201     202               volvo 144ea        sedan      109.1    3.15  19045.0
# 202     203               volvo 244dl        sedan      109.1    2.87  21485.0
# 203     204                 volvo 246        sedan      109.1    3.40  22470.0
# 204     205               volvo 264gl        sedan      109.1    3.15  22625.0
#
# [205 rows x 6 columns]

# %% [markdown]
# ##### Izbacivanje određene kolone

# %%
car_price_df.drop(['symboling', 'fueltype', 'aspiration', 'doornumber', 'carbody', 'drivewheel', 'enginelocation','wheelbase',
 'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio',
 'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg'], axis=1)
# Out:
#      car_ID                   CarName  stroke    price
# 0         1        alfa-romero giulia    2.68  13495.0
# 1         2       alfa-romero stelvio    2.68  16500.0
# 2         3  alfa-romero Quadrifoglio    3.47  16500.0
# 3         4               audi 100 ls    3.40  13950.0
# 4         5                audi 100ls    3.40  17450.0
# ..      ...                       ...     ...      ...
# 200     201           volvo 145e (sw)    3.15  16845.0
# 201     202               volvo 144ea    3.15  19045.0
# 202     203               volvo 244dl    2.87  21485.0
# 203     204                 volvo 246    3.40  22470.0
# 204     205               volvo 264gl    3.15  22625.0
#
# [205 rows x 4 columns]

# %% [markdown]
# ##### Sabiranje svih vrednosti u određenoj koloni

# %%
car_price_df['price'].sum()
# Out:
# 2721725.667

# %% [markdown]
# ##### Maksimalna vrednost cene automobila

# %%
car_price_df['price'].max()
# Out:
# 45400.0

# %% [markdown]
# ##### Odrediti srednju cenu automobila i standardno odstupanje

# %%
car_price_df['price'].mean()
# Out:
# 13276.710570731706

# %%
car_price_df['price'].std()
# Out:
# 7988.85233174315

# %% [markdown]
# ##### Izdvajanje podataka o automobilima kojima je cena manja od 5500

# %%
car_price_df.loc[car_price_df['price'] < 5500.0]
# Out:
#      car_ID  symboling                CarName fueltype aspiration doornumber  \
# 18       19          2       chevrolet impala      gas        std        two
# 32       33          1            honda civic      gas        std        two
# 50       51          1              maxda rx3      gas        std        two
# 76       77          2      mitsubishi mirage      gas        std        two
# 89       90          1           Nissan versa      gas        std        two
# 138     139          2                 subaru      gas        std        two
# 150     151          1  toyota corona mark ii      gas        std        two
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 18   hatchback        fwd          front       88.4  ...          61
# 32   hatchback        fwd          front       93.7  ...          79
# 50   hatchback        fwd          front       93.1  ...          91
# 76   hatchback        fwd          front       93.7  ...          92
# ...

# %%
car_price_df[car_price_df['price'] < 5500.0]
# Out:
#      car_ID  symboling                CarName fueltype aspiration doornumber  \
# 18       19          2       chevrolet impala      gas        std        two
# 32       33          1            honda civic      gas        std        two
# 50       51          1              maxda rx3      gas        std        two
# 76       77          2      mitsubishi mirage      gas        std        two
# 89       90          1           Nissan versa      gas        std        two
# 138     139          2                 subaru      gas        std        two
# 150     151          1  toyota corona mark ii      gas        std        two
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 18   hatchback        fwd          front       88.4  ...          61
# 32   hatchback        fwd          front       93.7  ...          79
# 50   hatchback        fwd          front       93.1  ...          91
# 76   hatchback        fwd          front       93.7  ...          92
# ...

# %% [markdown]
# ##### Primena linearne transformacije na celu kolonu

# %%
car_price_df['price'] = (car_price_df['price'] + 2)/2
car_price_df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %% [markdown]
# ##### Naći informacije o svim kolima modela volvo 246

# %%
car_price_df[car_price_df['CarName'] == "volvo 144ea"]
# Out:
#      car_ID  symboling      CarName fueltype aspiration doornumber carbody  \
# 195     196         -1  volvo 144ea      gas        std       four   wagon
# 201     202         -1  volvo 144ea      gas      turbo       four   sedan
#
#     drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 195        rwd          front      104.3  ...         141        mpfi
# 201        rwd          front      109.1  ...         141        mpfi
#
#      boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 195       3.78    3.15              9.5        114     5400      23
# 201       3.78    3.15              8.7        160     5300      19
#
#      highwaympg   price
# 195          28  6708.5
# 201          25  9523.5
#
# [2 rows x 26 columns]

# %% [markdown]
# ##### Primeniti matematičke operacije na celu kolonu

# %%
car_price_df['price'] = car_price_df['price'].apply(np.sqrt) 
car_price_df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
car_price_df['price'] = car_price_df['price'].apply(lambda x : x*x + 12)
car_price_df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %% [markdown]
# ##### Prikaz cene automobila na histogramu

# %%
car_price_df['price'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### Broj instanci svake marke automobila

# %%
car_price_df['CarName'].value_counts()
# Out:
# CarName
# toyota corona           6
# toyota corolla          6
# peugeot 504             6
# subaru dl               4
# mitsubishi mirage g4    3
#                        ..
# mazda glc 4             1
# mazda rx2 coupe         1
# maxda glc deluxe        1
# maxda rx3               1
# volvo 246               1
# Name: count, Length: 147, dtype: int64

# %% [markdown]
# ##### Promena vrednosti na određenim pozicijama u dataFrame-u

# %%
car_price_df.loc[0:3, ['wheelbase', 'price']] = 50
car_price_df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %% [markdown]
# ##### Dodavanje novog reda u dataFrame

# %%
car_price_df.loc['novi_red'] = 0
car_price_df
# Out:
#           car_ID  symboling                   CarName fueltype aspiration  \
# 0              1          3        alfa-romero giulia      gas        std
# 1              2          3       alfa-romero stelvio      gas        std
# 2              3          1  alfa-romero Quadrifoglio      gas        std
# 3              4          2               audi 100 ls      gas        std
# 4              5          2                audi 100ls      gas        std
# ...          ...        ...                       ...      ...        ...
# 201          202         -1               volvo 144ea      gas      turbo
# 202          203         -1               volvo 244dl      gas        std
# 203          204         -1                 volvo 246   diesel      turbo
# 204          205         -1               volvo 264gl      gas      turbo
# novi_red       0          0                         0        0          0
#
#          doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %% [markdown]
# ##### Resetovanje svih cena automobila na nulu

# %%
car_price_df.loc[:, 'price'] = 0
car_price_df
# Out:
#           car_ID  symboling                   CarName fueltype aspiration  \
# 0              1          3        alfa-romero giulia      gas        std
# 1              2          3       alfa-romero stelvio      gas        std
# 2              3          1  alfa-romero Quadrifoglio      gas        std
# 3              4          2               audi 100 ls      gas        std
# 4              5          2                audi 100ls      gas        std
# ...          ...        ...                       ...      ...        ...
# 201          202         -1               volvo 144ea      gas      turbo
# 202          203         -1               volvo 244dl      gas        std
# 203          204         -1                 volvo 246   diesel      turbo
# 204          205         -1               volvo 264gl      gas      turbo
# novi_red       0          0                         0        0          0
#
#          doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %% [markdown]
# ##### Sortiranje dataFramea po ceni automobila

# %%
#because we've set the price to 0
car_price_df = car_price_df.sort_values(by = 'highwaympg', ascending = False)
car_price_df
# Out:
#           car_ID  symboling                          CarName fueltype  \
# 30            31          2                      honda civic      gas
# 18            19          2                 chevrolet impala      gas
# 90            91          1                      nissan gt-r   diesel
# 160          161          0                    toyota corona      gas
# 159          160          0                   toyota corolla   diesel
# ...          ...        ...                              ...      ...
# 71            72         -1          buick opel isuzu deluxe      gas
# 49            50          0                        jaguar xk      gas
# 73            74          0            buick century special      gas
# 74            75          1  buick regal sport coupe (turbo)      gas
# novi_red       0          0                                0        0
#
#          aspiration doornumber    carbody drivewheel enginelocation  \
# ...

# %% [markdown]
# ##### Opis statistike dataFrame-a

# %%
df_new = car_price_df.describe()
df_new
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  206.000000  206.000000  206.000000  206.000000  206.000000  206.000000
# mean   102.500000    0.830097   97.444660  173.204369   65.587864   53.464078
# std     59.611241    1.243625   11.278948   17.277741    5.066167    4.466894
# min      0.000000   -2.000000    0.000000    0.000000    0.000000    0.000000
# 25%     51.250000    0.000000   94.500000  166.300000   64.025000   52.000000
# 50%    102.500000    1.000000   96.900000  173.200000   65.500000   54.100000
# 75%    153.750000    2.000000  102.300000  182.750000   66.825000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   206.000000  206.000000  206.000000  206.000000        206.000000
# mean   2543.160194  126.291262    3.313592    3.239612         10.093301
# ...

# %% [markdown]
# ##### Nadovezivanje dva dataFrame-a

# %%
df = pd.concat([df_new, car_price_df])
df
# Out:
#               car_ID   symboling   wheelbase   carlength    carwidth  \
# count     206.000000  206.000000  206.000000  206.000000  206.000000
# mean      102.500000    0.830097   97.444660  173.204369   65.587864
# std        59.611241    1.243625   11.278948   17.277741    5.066167
# min         0.000000   -2.000000    0.000000    0.000000    0.000000
# 25%        51.250000    0.000000   94.500000  166.300000   64.025000
# ...              ...         ...         ...         ...         ...
# 71         72.000000   -1.000000  115.600000  202.600000   71.700000
# 49         50.000000    0.000000  102.000000  191.700000   70.600000
# 73         74.000000    0.000000  120.900000  208.100000   71.700000
# 74         75.000000    1.000000  112.000000  199.200000   72.000000
# novi_red    0.000000    0.000000    0.000000    0.000000    0.000000
#
#            carheight   curbweight  enginesize   boreratio      stroke  ...  \
# ...

# %% [markdown]
# ##### Čuvanje novog dataFramea

# %%
df.to_csv("novi.csv", index = False)
